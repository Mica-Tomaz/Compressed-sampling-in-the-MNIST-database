# %%
# Bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# Metricas e ferramentas de processamento do SKLEARN

from sklearn import metrics  # Métricas adicionais para avaliação de modelos
from sklearn.model_selection import train_test_split, KFold  # Funções para dividir dados em conjuntos de treino e teste, e para validação cruzada
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report  # Métricas de avaliação de modelos de classificação
from sklearn.preprocessing import StandardScaler  # Ferramenta para pré-processamento de dados (escalonamento)
from sklearn.model_selection import cross_val_score
from sklearn.metrics import recall_score, precision_score, f1_score  # Métricas de avaliação de modelos de classificação

# Bivlioteca TensorFlow

from tensorflow.keras.models import Sequential  # Modelo de rede neural sequencial do Keras
from tensorflow.keras.layers import *  # Camadas de uma rede neural no Keras
from tensorflow.keras.callbacks import ModelCheckpoint  # Callback para salvar o modelo durante o treinamento
from tensorflow.keras.losses import MeanSquaredError  # Função de perda para regressão no Keras
from tensorflow.keras.metrics import RootMeanSquaredError  # Métrica adicional para avaliação de modelos de regressão
from tensorflow.keras.optimizers import Adam  # Otimizador Adam para treinamento de redes neurais no Keras

# %%
# Versão do TensorFlow utilizada.
tf.__version__
# Out:
# '2.17.0'

# %%
# Importando a biblioteca MNIST.
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
# Exemplo de uma imagem do Banco de dados MNIST, disposta em uma matriz 28x28.
plt.imshow(X_train[5],cmap='gray')

# %%
# Transformando a matriz 28x28 em um vetor coluna de 784x1.
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)
X_train[1].shape
# Out:
# (784,)

# %%
# Normalizando o banco de dados por escalonamento por valor máximo.
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Criando um modelo sequencial
model = tf.keras.models.Sequential()

# Criando a camada de entrada de 784 neurônios e a 1º camada oculta com 128 neurônios (Função de ativação Relu).
model.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784, )))

#Função Dropout
model.add(tf.keras.layers.Dropout(0.2))

# 2º camada oculta com 100 neurônios
model.add(tf.keras.layers.Dense(units=100, activation='relu'))

# Função Dropout
model.add(tf.keras.layers.Dropout(0.2))

# 3º camada oculta com 64 neurônios
model.add(tf.keras.layers.Dense(units=64, activation='relu'))

# Função Dropout
model.add(tf.keras.layers.Dropout(0.2))

# Criando a camada de saída com 10 neurônios e função de ativação softmax
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
# Out:
# c:\Users\Micael\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilando o modelo
cp1 = ModelCheckpoint('model/melhor_modelo.keras', save_best_only=True)
model.compile(loss = 'sparse_categorical_crossentropy' , optimizer = Adam(learning_rate=0.001), metrics = ['sparse_categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        12,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         6,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120,494 (470.68 KB)
#  Trainable params: 120,494 (470.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Treinando e validando o modelo Neural com 40 épocas de treinamento
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, callbacks=[cp1])
# Out:
# Epoch 1/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.8474 - sparse_categorical_accuracy: 0.6937 - val_loss: 0.4444 - val_sparse_categorical_accuracy: 0.8406
# Epoch 2/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4611 - sparse_categorical_accuracy: 0.8364 - val_loss: 0.3931 - val_sparse_categorical_accuracy: 0.8590
# Epoch 3/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.4105 - sparse_categorical_accuracy: 0.8528 - val_loss: 0.3980 - val_sparse_categorical_accuracy: 0.8532
# Epoch 4/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3915 - sparse_categorical_accuracy: 0.8580 - val_loss: 0.3775 - val_sparse_categorical_accuracy: 0.8639
# Epoch 5/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.3668 - sparse_categorical_accuracy: 0.8656 - val_loss: 0.3502 - val_sparse_categorical_accuracy: 0.8733
# Epoch 6/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.3559 - sparse_categorical_accuracy: 0.8731 - val_loss: 0.3494 - val_sparse_categorical_accuracy: 0.8699
# Epoch 7/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.3428 - sparse_categorical_accuracy: 0.8768 - val_loss: 0.3555 - val_sparse_categorical_accuracy: 0.8715
# Epoch 8/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.3355 - sparse_categorical_accuracy: 0.8798 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8739
# Epoch 9/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.3256 - sparse_categorical_accuracy: 0.8811 - val_loss: 0.3405 - val_sparse_categorical_accuracy: 0.8775
# Epoch 10/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.3263 - sparse_categorical_accuracy: 0.8803 - val_loss: 0.3377 - val_sparse_categorical_accuracy: 0.8785
# Epoch 11/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3167 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.3406 - val_sparse_categorical_accuracy: 0.8783
# Epoch 12/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.3069 - sparse_categorical_accuracy: 0.8883 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.8779
# Epoch 13/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3056 - sparse_categorical_accuracy: 0.8887 - val_loss: 0.3319 - val_sparse_categorical_accuracy: 0.8805
# Epoch 14/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.3014 - sparse_categorical_accuracy: 0.8901 - val_loss: 0.3317 - val_sparse_categorical_accuracy: 0.8819
# Epoch 15/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.2946 - sparse_categorical_accuracy: 0.8921 - val_loss: 0.3308 - val_sparse_categorical_accuracy: 0.8830
# Epoch 16/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.2975 - sparse_categorical_accuracy: 0.8912 - val_loss: 0.3276 - val_sparse_categorical_accuracy: 0.8848
# Epoch 17/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.2930 - sparse_categorical_accuracy: 0.8918 - val_loss: 0.3283 - val_sparse_categorical_accuracy: 0.8782
# Epoch 18/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2895 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.3286 - val_sparse_categorical_accuracy: 0.8820
# Epoch 19/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2884 - sparse_categorical_accuracy: 0.8937 - val_loss: 0.3358 - val_sparse_categorical_accuracy: 0.8821
# Epoch 20/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2805 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.3445 - val_sparse_categorical_accuracy: 0.8778
# Epoch 21/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2850 - sparse_categorical_accuracy: 0.8972 - val_loss: 0.3316 - val_sparse_categorical_accuracy: 0.8841
# Epoch 22/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2759 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.3414 - val_sparse_categorical_accuracy: 0.8831
# Epoch 23/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2720 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.3235 - val_sparse_categorical_accuracy: 0.8863
# Epoch 24/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2665 - sparse_categorical_accuracy: 0.9029 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8854
# Epoch 25/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2677 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.3413 - val_sparse_categorical_accuracy: 0.8791
# Epoch 26/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2639 - sparse_categorical_accuracy: 0.9025 - val_loss: 0.3344 - val_sparse_categorical_accuracy: 0.8829
# Epoch 27/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2616 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.3408 - val_sparse_categorical_accuracy: 0.8794
# Epoch 28/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2612 - sparse_categorical_accuracy: 0.9032 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8830
# Epoch 29/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2593 - sparse_categorical_accuracy: 0.9057 - val_loss: 0.3309 - val_sparse_categorical_accuracy: 0.8874
# Epoch 30/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2572 - sparse_categorical_accuracy: 0.9060 - val_loss: 0.3289 - val_sparse_categorical_accuracy: 0.8878
# Epoch 31/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2557 - sparse_categorical_accuracy: 0.9060 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.8865
# Epoch 32/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2597 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.3311 - val_sparse_categorical_accuracy: 0.8878
# Epoch 33/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2572 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.3308 - val_sparse_categorical_accuracy: 0.8886
# Epoch 34/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2557 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.3288 - val_sparse_categorical_accuracy: 0.8896
# Epoch 35/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2494 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.3397 - val_sparse_categorical_accuracy: 0.8871
# Epoch 36/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2486 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.3412 - val_sparse_categorical_accuracy: 0.8841
# Epoch 37/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2480 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.3416 - val_sparse_categorical_accuracy: 0.8897
# Epoch 38/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2504 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.3354 - val_sparse_categorical_accuracy: 0.8870
# Epoch 39/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.3337 - val_sparse_categorical_accuracy: 0.8895
# Epoch 40/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2403 - sparse_categorical_accuracy: 0.9105 - val_loss: 0.3428 - val_sparse_categorical_accuracy: 0.8831

# %%
# Obtendo a acurácia do histórico
accuracy = history.history['sparse_categorical_accuracy']
val_accuracy = history.history['val_sparse_categorical_accuracy']

# Obtendo as épocas
epochs = range(1, len(accuracy) + 1)

# Plotando a acurácia
plt.plot(epochs, accuracy, '-', label='Accuracy de treino')
plt.plot(epochs, val_accuracy, '--', label='Accuracy de validação')
#plt.title('')
plt.xlabel('Épocas de treinamento')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# Obtendo a loss do histórico
loss = history.history['loss']
val_loss = history.history['val_loss']

# Obtendo as épocas
epochs = range(1, len(accuracy) + 1)

# Plotando a acurácia
plt.plot(epochs, loss, '-', label='Loss de treino')
plt.plot(epochs, val_loss, '--', label='Loss de validação')
#plt.title('')
plt.xlabel('Épocas de treinamento')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
# Testando o modelo
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3462 - sparse_categorical_accuracy: 0.8822

# %%
# Obtém as previsões do modelo para os dados de teste
y_pred = model.predict(X_test)

# Converte as previsões para rótulos binários (0 ou 1) para cada classe individualmente
y_pred_binary = np.argmax(y_pred, axis=1)

# Calcula o recall para cada classe individualmente
recall_per_class = recall_score(y_test, y_pred_binary, average=None)

# Calcula a precisão para cada classe individualmente
precision_per_class = precision_score(y_test, y_pred_binary, average=None)

# Calcula o F-score para cada classe individualmente
f_score_per_class = f1_score(y_test, y_pred_binary, average=None)

# Calcula a média ponderada dos recalls
weighted_recall = recall_score(y_test, y_pred_binary, average='weighted')

# Calcula a média ponderada da precisão
weighted_precision = precision_score(y_test, y_pred_binary, average='weighted')

# Calcula a média ponderada do F-score
weighted_f_score = f1_score(y_test, y_pred_binary, average='weighted')

# Imprime a Accuracy
print("Accuracy: {:.4f}".format(test_accuracy))

# Imprime a média ponderada da precisão
print("Weighted Precision: {:.4f}".format(weighted_precision))

# Imprime a média ponderada do F-score
print("Weighted F-score: {:.4f}".format(weighted_f_score))

# Imprime a média ponderada dos recalls
print("Weighted Recall: {:.4f}".format(weighted_recall))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.8831
# Weighted Precision: 0.8838
# Weighted F-score: 0.8832
# Weighted Recall: 0.8831
